# %%
# dont ask me, and I won't clean it..
import numpy as np
import glob
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import os
# %tensorflow_version 1.x
from PIL import Image
from keras import layers
from keras.models import Model
from keras.models import load_model
from keras.utils.vis_utils import plot_model  #plotting the model structure
from keras import callbacks
from datetime import datetime
import os
import cv2
import string
import numpy as np


from keras.models import Model
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
import warnings
warnings.filterwarnings('ignore')
from keras import models
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint


from keras import layers        # functional 
from keras.models import Model
from keras.models import load_model
from keras import callbacks
import cv2
import string
import numpy as np
from datetime import datetime
from packaging import version
import tensorflow as tf
from tensorflow import keras
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
! wget "https://ndownloader.figshare.com/files/22150851" -O railway_captcha7.tar.gz
# Out:
# --2020-04-08 03:31:23--  https://ndownloader.figshare.com/files/22150851
# Resolving ndownloader.figshare.com (ndownloader.figshare.com)... 34.242.31.21, 34.249.41.128, 34.246.143.19, ...
# Connecting to ndownloader.figshare.com (ndownloader.figshare.com)|34.242.31.21|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/22150851/railway_captcha7.tar.gz [following]
# --2020-04-08 03:31:24--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/22150851/railway_captcha7.tar.gz
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.57.3
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.57.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 303180031 (289M) [application/gzip]
# Saving to: ‘railway_captcha7.tar.gz’
#
# railway_captcha7.ta 100%[===================>] 289.13M  11.7MB/s    in 27s
#
# 2020-04-08 03:31:52 (10.9 MB/s) - ‘railway_captcha7.tar.gz’ saved [303180031/303180031]

# %%
# !tar -xvf railway_captcha7.tar.gz > /dev/null
! echo "Untaring... done..."
# Out:
# Untaring... done...

# %%
png_files = glob.glob('railway_captcha7/*.jpg')
print("Total # of files => ",len(png_files))
png_files[0]
# Out:
# Total # of files =>  100000
# 'railway_captcha7/6555529_73568.jpg'

# %%
symbols = "ABCDEFGHIJKLMNOPQRSTUVWXYZ" + '0123456789' # These are all symbols the captchas will have
num_symbols = len(symbols)
img = np.array(Image.open(png_files[0]))
shape_ = img.shape
print(shape_, num_symbols)
# Out:
# (60, 200, 3) 36

# %%
img_path = png_files[1]
img = cv2.imread(img_path,cv2.IMREAD_UNCHANGED)
plt.imshow(img)
plt.show()

# %%
img_path = png_files[1]
img_gray = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')
plt.show()
print(img_gray.shape)
# Out:
# (60, 200)

# %%
# perform OTSU's thresholding
ret,thresh = cv2.threshold(img_gray,127,255,cv2.THRESH_BINARY_INV)
plt.imshow(thresh,cmap='gray')
plt.show()
print(thresh.shape)
# Out:
# (60, 200)

# %%
kernel = np.ones((2,2),np.uint8)
#dialate = cv2.dilate(thresh,kernel,iterations = 1)
erosion = cv2.erode(thresh,kernel,iterations = 1)
plt.imshow(erosion,cmap='gray')
plt.show()

# %%
#kernel = np.ones((2,2),np.uint8)
dialate = cv2.dilate(erosion,kernel,iterations = 2)
#erosion = cv2.erode(thresh,kernel,iterations = 1)
plt.imshow(dialate,cmap='gray')
plt.show()

# %%
total_img = 36
num_pr = 6 # number per row

counter = 1
plt.figure(figsize=(30,15))
plt.axis('off')
for item in png_files[:total_img]:
  image = cv2.imread(item, cv2.IMREAD_GRAYSCALE)
  #img = cv2.resize(img, (200,60), interpolation = cv2.INTER_AREA)
  ret,thresh = cv2.threshold(image,127,255,cv2.THRESH_BINARY_INV)
  # firstly perform erosion
  erosion = cv2.erode(thresh,kernel,iterations = 1)
  # perform dialation
  dialate = cv2.dilate(erosion,kernel,iterations = 2)
  
  #print(pred)
  image_bckup = dialate.copy()
  plt.subplot(num_pr, num_pr, counter)
  #print("item => ",item)
  #print("item => ",str(item.split('_')[1]).split('/')[1])
  plt.title("Name = {}".format(str(item.split('_')[1]).split('/')[1]),fontsize=20).set_color('black')
  plt.axis('off')
  plt.imshow(image_bckup, cmap=plt.get_cmap('gray'))
  counter += 1
  #break
plt.show()

# %%
def create_model():
  in_ = Input(shape=img_shape)
  out = in_
  out = Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu')(out)
  out = Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Dropout(0.3)(out)
  out = Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(out)
  out = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Dropout(0.3)(out)
  out = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(out)
  out = Conv2D(filters=128, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Dropout(0.3)(out)
  out = Conv2D(filters=256, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Flatten()(out)
  out = Dropout(0.3)(out)
  out = [Dense(36, name='digit1', activation='softmax')(out),\
        Dense(36, name='digit2', activation='softmax')(out),\
        Dense(36, name='digit3', activation='softmax')(out),\
        Dense(36, name='digit4', activation='softmax')(out),\
        Dense(36, name='digit5', activation='softmax')(out),\
        Dense(36, name='digit6', activation='softmax')(out),
        Dense(36, name='digit7', activation='softmax')(out)
        ]
  model = Model(inputs=in_, outputs=out)
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
from tqdm import tqdm
kernel = np.ones((2,2),np.uint8)
letters_in_captcha = 7
def preprocess_data():
  n_samples = len(os.listdir('railway_captcha7/'))
  X = np.zeros((n_samples, 200, 60, 1)) #1070*50*200
  print(num_symbols,n_samples)
  y = np.zeros((letters_in_captcha, n_samples, num_symbols)) #5*1070*36
  for i, pic in tqdm(enumerate(os.listdir('railway_captcha7/'))):
    # Read image as grayscale
    img = cv2.imread(os.path.join('railway_captcha7/', pic), cv2.IMREAD_GRAYSCALE)
    ret,thresh = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
    # firstly perform erosion
    erosion = cv2.erode(thresh,kernel,iterations = 1)
    # perform dialation
    dialate = cv2.dilate(erosion,kernel,iterations = 2)
    img = dialate.copy()
    pic_target = pic.split('_')[0]
    img = img / 255.0
    #plt.imshow(img,cmap='gray')
    img = np.reshape(img, (200, 60, 1))
    # Define targets and code them using OneHotEncoding
    targs = np.zeros((letters_in_captcha, num_symbols))
    #print("num symbols = ",num_symbols)
    for j, l in enumerate(pic_target):
      ind = symbols.find(l)
      targs[j, ind] = 1
    X[i] = img
    y[:, i] = targs
    
  # Return final data
  return X, y

X, y = preprocess_data()
# Out:
# 0it [00:00, ?it/s]
# 36 100000
# 100000it [00:21, 4587.07it/s]

# %%
X_train, y_train = X[:90000], y[:, :90000]
X_test, y_test = X[90000:], y[:, 90000:]

# %%
plt.imshow(X_train[0].reshape((60,200)),cmap='gray')
plt.show()
print(X_train[0].shape)
# Out:
# (200, 60, 1)

# %%
img_shape = (200, 60, 1)
model=create_model();
model.summary();
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 60, 1)   0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 200, 60, 32)  320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 198, 58, 32)  9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 198, 58, 32)  128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 99, 29, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 99, 29, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 99, 29, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 97, 27, 64)   36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 97, 27, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 48, 13, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 48, 13, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 13, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 46, 11, 128)  147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 46, 11, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 23, 5, 128)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 23, 5, 128)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 21, 3, 256)   295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 21, 3, 256)   1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 10, 1, 256)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2560)         0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 2560)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# digit1 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit2 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit3 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit4 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit5 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit6 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# __________________________________________________________________________________________________
# digit7 (Dense)                  (None, 36)           92196       dropout_4[0][0]
# ==================================================================================================
# Total params: 1,228,892
# Trainable params: 1,227,932
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True,dpi=60)

# %%
# for storing logs into tensorboard
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

hist = model.fit(X_train, [y_train[0], y_train[1], y_train[2],y_train[3],y_train[4],y_train[5],y_train[6]], batch_size=32, epochs=30,verbose=1, validation_split=0.2,callbacks=[tensorboard_callback])
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 72000 samples, validate on 18000 samples
# Epoch 1/30
# 72000/72000 [==============================] - 105s 1ms/step - loss: 18.4949 - digit1_loss: 2.6422 - digit2_loss: 2.6467 - digit3_loss: 2.6398 - digit4_loss: 2.6447 - digit5_loss: 2.6411 - digit6_loss: 2.6427 - digit7_loss: 2.6376 - digit1_acc: 0.1068 - digit2_acc: 0.1050 - digit3_acc: 0.1083 - digit4_acc: 0.1076 - digit5_acc: 0.1089 - digit6_acc: 0.1084 - digit7_acc: 0.1076 - val_loss: 26.2717 - val_digit1_loss: 3.8089 - val_digit2_loss: 3.6458 - val_digit3_loss: 3.7477 - val_digit4_loss: 3.7839 - val_digit5_loss: 3.7431 - val_digit6_loss: 3.7758 - val_digit7_loss: 3.7666 - val_digit1_acc: 0.0203 - val_digit2_acc: 0.0318 - val_digit3_acc: 0.0206 - val_digit4_acc: 0.0273 - val_digit5_acc: 0.0128 - val_digit6_acc: 0.0212 - val_digit7_acc: 0.0179
# Epoch 2/30
# 72000/72000 [==============================] - 96s 1ms/step - loss: 16.7353 - digit1_loss: 2.3971 - digit2_loss: 2.3840 - digit3_loss: 2.3695 - digit4_loss: 2.4100 - digit5_loss: 2.3904 - digit6_loss: 2.3882 - digit7_loss: 2.3961 - digit1_acc: 0.1587 - digit2_acc: 0.1637 - digit3_acc: 0.1678 - digit4_acc: 0.1554 - digit5_acc: 0.1635 - digit6_acc: 0.1612 - digit7_acc: 0.1577 - val_loss: 18.7053 - val_digit1_loss: 2.6213 - val_digit2_loss: 2.7040 - val_digit3_loss: 2.5874 - val_digit4_loss: 2.7877 - val_digit5_loss: 2.7102 - val_digit6_loss: 2.6111 - val_digit7_loss: 2.6837 - val_digit1_acc: 0.2046 - val_digit2_acc: 0.2070 - val_digit3_acc: 0.2259 - val_digit4_acc: 0.1849 - val_digit5_acc: 0.2121 - val_digit6_acc: 0.2148 - val_digit7_acc: 0.2009
# Epoch 3/30
# 72000/72000 [==============================] - 95s 1ms/step - loss: 14.7539 - digit1_loss: 2.1266 - digit2_loss: 2.0812 - digit3_loss: 2.0613 - digit4_loss: 2.1450 - digit5_loss: 2.1153 - digit6_loss: 2.0937 - digit7_loss: 2.1308 - digit1_acc: 0.2414 - digit2_acc: 0.2648 - digit3_acc: 0.2710 - digit4_acc: 0.2397 - digit5_acc: 0.2536 - digit6_acc: 0.2649 - digit7_acc: 0.2390 - val_loss: 13.6380 - val_digit1_loss: 1.9423 - val_digit2_loss: 1.9192 - val_digit3_loss: 1.8790 - val_digit4_loss: 1.9906 - val_digit5_loss: 1.9677 - val_digit6_loss: 1.9378 - val_digit7_loss: 2.0015 - val_digit1_acc: 0.3091 - val_digit2_acc: 0.3391 - val_digit3_acc: 0.3550 - val_digit4_acc: 0.2912 - val_digit5_acc: 0.3171 - val_digit6_acc: 0.3263 - val_digit7_acc: 0.2872
# Epoch 4/30
# 72000/72000 [==============================] - 90s 1ms/step - loss: 13.5518 - digit1_loss: 1.9677 - digit2_loss: 1.8871 - digit3_loss: 1.8667 - digit4_loss: 2.0035 - digit5_loss: 1.9450 - digit6_loss: 1.8989 - digit7_loss: 1.9829 - digit1_acc: 0.3090 - digit2_acc: 0.3529 - digit3_acc: 0.3615 - digit4_acc: 0.3014 - digit5_acc: 0.3299 - digit6_acc: 0.3517 - digit7_acc: 0.3014 - val_loss: 13.3665 - val_digit1_loss: 1.9072 - val_digit2_loss: 1.9062 - val_digit3_loss: 1.8279 - val_digit4_loss: 1.9711 - val_digit5_loss: 1.9546 - val_digit6_loss: 1.8518 - val_digit7_loss: 1.9477 - val_digit1_acc: 0.3714 - val_digit2_acc: 0.3776 - val_digit3_acc: 0.4097 - val_digit4_acc: 0.3593 - val_digit5_acc: 0.3613 - val_digit6_acc: 0.3953 - val_digit7_acc: 0.3562
# Epoch 5/30
# 72000/72000 [==============================] - 91s 1ms/step - loss: 12.5345 - digit1_loss: 1.8377 - digit2_loss: 1.7273 - digit3_loss: 1.7077 - digit4_loss: 1.8765 - digit5_loss: 1.7924 - digit6_loss: 1.7370 - digit7_loss: 1.8559 - digit1_acc: 0.3695 - digit2_acc: 0.4222 - digit3_acc: 0.4350 - digit4_acc: 0.3589 - digit5_acc: 0.3978 - digit6_acc: 0.4228 - digit7_acc: 0.3589 - val_loss: 11.4565 - val_digit1_loss: 1.6422 - val_digit2_loss: 1.5888 - val_digit3_loss: 1.5647 - val_digit4_loss: 1.7066 - val_digit5_loss: 1.6423 - val_digit6_loss: 1.6032 - val_digit7_loss: 1.7087 - val_digit1_acc: 0.4670 - val_digit2_acc: 0.4881 - val_digit3_acc: 0.4886 - val_digit4_acc: 0.4357 - val_digit5_acc: 0.4598 - val_digit6_acc: 0.4813 - val_digit7_acc: 0.4352
# Epoch 6/30
# 72000/72000 [==============================] - 95s 1ms/step - loss: 11.7837 - digit1_loss: 1.7361 - digit2_loss: 1.6144 - digit3_loss: 1.5925 - digit4_loss: 1.7791 - digit5_loss: 1.6847 - digit6_loss: 1.6203 - digit7_loss: 1.7566 - digit1_acc: 0.4143 - digit2_acc: 0.4687 - digit3_acc: 0.4795 - digit4_acc: 0.4010 - digit5_acc: 0.4434 - digit6_acc: 0.4668 - digit7_acc: 0.4033 - val_loss: 10.7048 - val_digit1_loss: 1.5709 - val_digit2_loss: 1.4751 - val_digit3_loss: 1.4263 - val_digit4_loss: 1.6261 - val_digit5_loss: 1.5246 - val_digit6_loss: 1.4690 - val_digit7_loss: 1.6129 - val_digit1_acc: 0.4857 - val_digit2_acc: 0.5440 - val_digit3_acc: 0.5533 - val_digit4_acc: 0.4729 - val_digit5_acc: 0.5164 - val_digit6_acc: 0.5425 - val_digit7_acc: 0.4769
# Epoch 7/30
# 72000/72000 [==============================] - 94s 1ms/step - loss: 11.1871 - digit1_loss: 1.6518 - digit2_loss: 1.5245 - digit3_loss: 1.5015 - digit4_loss: 1.7007 - digit5_loss: 1.5945 - digit6_loss: 1.5356 - digit7_loss: 1.6785 - digit1_acc: 0.4482 - digit2_acc: 0.5040 - digit3_acc: 0.5147 - digit4_acc: 0.4315 - digit5_acc: 0.4783 - digit6_acc: 0.5007 - digit7_acc: 0.4368 - val_loss: 10.0845 - val_digit1_loss: 1.4798 - val_digit2_loss: 1.3757 - val_digit3_loss: 1.3291 - val_digit4_loss: 1.5594 - val_digit5_loss: 1.4274 - val_digit6_loss: 1.3800 - val_digit7_loss: 1.5331 - val_digit1_acc: 0.5309 - val_digit2_acc: 0.5789 - val_digit3_acc: 0.5906 - val_digit4_acc: 0.5013 - val_digit5_acc: 0.5604 - val_digit6_acc: 0.5728 - val_digit7_acc: 0.5113
# Epoch 8/30
# 72000/72000 [==============================] - 95s 1ms/step - loss: 10.6756 - digit1_loss: 1.5879 - digit2_loss: 1.4420 - digit3_loss: 1.4220 - digit4_loss: 1.6428 - digit5_loss: 1.5156 - digit6_loss: 1.4546 - digit7_loss: 1.6107 - digit1_acc: 0.4717 - digit2_acc: 0.5338 - digit3_acc: 0.5438 - digit4_acc: 0.4557 - digit5_acc: 0.5098 - digit6_acc: 0.5292 - digit7_acc: 0.4640 - val_loss: 9.5803 - val_digit1_loss: 1.4001 - val_digit2_loss: 1.3013 - val_digit3_loss: 1.2570 - val_digit4_loss: 1.4899 - val_digit5_loss: 1.3456 - val_digit6_loss: 1.3013 - val_digit7_loss: 1.4852 - val_digit1_acc: 0.5647 - val_digit2_acc: 0.6065 - val_digit3_acc: 0.6208 - val_digit4_acc: 0.5321 - val_digit5_acc: 0.5946 - val_digit6_acc: 0.6042 - val_digit7_acc: 0.5302
# Epoch 9/30
# 72000/72000 [==============================] - 90s 1ms/step - loss: 10.2427 - digit1_loss: 1.5289 - digit2_loss: 1.3714 - digit3_loss: 1.3548 - digit4_loss: 1.5910 - digit5_loss: 1.4518 - digit6_loss: 1.3859 - digit7_loss: 1.5588 - digit1_acc: 0.4938 - digit2_acc: 0.5578 - digit3_acc: 0.5675 - digit4_acc: 0.4732 - digit5_acc: 0.5336 - digit6_acc: 0.5552 - digit7_acc: 0.4823 - val_loss: 9.2627 - val_digit1_loss: 1.3692 - val_digit2_loss: 1.2448 - val_digit3_loss: 1.2052 - val_digit4_loss: 1.4492 - val_digit5_loss: 1.3082 - val_digit6_loss: 1.2626 - val_digit7_loss: 1.4235 - val_digit1_acc: 0.5781 - val_digit2_acc: 0.6306 - val_digit3_acc: 0.6426 - val_digit4_acc: 0.5533 - val_digit5_acc: 0.6048 - val_digit6_acc: 0.6151 - val_digit7_acc: 0.5606
# Epoch 10/30
# 72000/72000 [==============================] - 95s 1ms/step - loss: 9.8745 - digit1_loss: 1.4771 - digit2_loss: 1.3168 - digit3_loss: 1.2941 - digit4_loss: 1.5472 - digit5_loss: 1.3903 - digit6_loss: 1.3372 - digit7_loss: 1.5119 - digit1_acc: 0.5131 - digit2_acc: 0.5800 - digit3_acc: 0.5889 - digit4_acc: 0.4925 - digit5_acc: 0.5525 - digit6_acc: 0.5749 - digit7_acc: 0.4979 - val_loss: 8.7496 - val_digit1_loss: 1.2887 - val_digit2_loss: 1.1685 - val_digit3_loss: 1.1326 - val_digit4_loss: 1.3796 - val_digit5_loss: 1.2278 - val_digit6_loss: 1.1817 - val_digit7_loss: 1.3706 - val_digit1_acc: 0.6178 - val_digit2_acc: 0.6616 - val_digit3_acc: 0.6699 - val_digit4_acc: 0.5820 - val_digit5_acc: 0.6393 - val_digit6_acc: 0.6539 - val_digit7_acc: 0.5810
# Epoch 11/30
# 72000/72000 [==============================] - 97s 1ms/step - loss: 9.5431 - digit1_loss: 1.4385 - digit2_loss: 1.2610 - digit3_loss: 1.2447 - digit4_loss: 1.5081 - digit5_loss: 1.3379 - digit6_loss: 1.2778 - digit7_loss: 1.4751 - digit1_acc: 0.5285 - digit2_acc: 0.5996 - digit3_acc: 0.6059 - digit4_acc: 0.5045 - digit5_acc: 0.5733 - digit6_acc: 0.5928 - digit7_acc: 0.5118 - val_loss: 8.4202 - val_digit1_loss: 1.2439 - val_digit2_loss: 1.1100 - val_digit3_loss: 1.0848 - val_digit4_loss: 1.3601 - val_digit5_loss: 1.1786 - val_digit6_loss: 1.1219 - val_digit7_loss: 1.3207 - val_digit1_acc: 0.6321 - val_digit2_acc: 0.6834 - val_digit3_acc: 0.6866 - val_digit4_acc: 0.5923 - val_digit5_acc: 0.6567 - val_digit6_acc: 0.6738 - val_digit7_acc: 0.6033
# Epoch 12/30
# 72000/72000 [==============================] - 97s 1ms/step - loss: 9.2222 - digit1_loss: 1.3943 - digit2_loss: 1.2079 - digit3_loss: 1.2023 - digit4_loss: 1.4649 - digit5_loss: 1.2905 - digit6_loss: 1.2259 - digit7_loss: 1.4364 - digit1_acc: 0.5444 - digit2_acc: 0.6181 - digit3_acc: 0.6210 - digit4_acc: 0.5214 - digit5_acc: 0.5900 - digit6_acc: 0.6128 - digit7_acc: 0.5266 - val_loss: 8.0586 - val_digit1_loss: 1.1933 - val_digit2_loss: 1.0606 - val_digit3_loss: 1.0232 - val_digit4_loss: 1.3006 - val_digit5_loss: 1.1219 - val_digit6_loss: 1.0731 - val_digit7_loss: 1.2859 - val_digit1_acc: 0.6536 - val_digit2_acc: 0.7003 - val_digit3_acc: 0.7098 - val_digit4_acc: 0.6166 - val_digit5_acc: 0.6814 - val_digit6_acc: 0.6934 - val_digit7_acc: 0.6167
# Epoch 13/30
# 72000/72000 [==============================] - 97s 1ms/step - loss: 8.9627 - digit1_loss: 1.3580 - digit2_loss: 1.1715 - digit3_loss: 1.1646 - digit4_loss: 1.4317 - digit5_loss: 1.2497 - digit6_loss: 1.1871 - digit7_loss: 1.3999 - digit1_acc: 0.5575 - digit2_acc: 0.6313 - digit3_acc: 0.6331 - digit4_acc: 0.5338 - digit5_acc: 0.6033 - digit6_acc: 0.6257 - digit7_acc: 0.5403 - val_loss: 7.9036 - val_digit1_loss: 1.1830 - val_digit2_loss: 1.0294 - val_digit3_loss: 1.0016 - val_digit4_loss: 1.2778 - val_digit5_loss: 1.0981 - val_digit6_loss: 1.0502 - val_digit7_loss: 1.2635 - val_digit1_acc: 0.6510 - val_digit2_acc: 0.7121 - val_digit3_acc: 0.7151 - val_digit4_acc: 0.6176 - val_digit5_acc: 0.6886 - val_digit6_acc: 0.7021 - val_digit7_acc: 0.6234
# Epoch 14/30
# 72000/72000 [==============================] - 91s 1ms/step - loss: 8.7299 - digit1_loss: 1.3302 - digit2_loss: 1.1349 - digit3_loss: 1.1244 - digit4_loss: 1.4025 - digit5_loss: 1.2111 - digit6_loss: 1.1573 - digit7_loss: 1.3694 - digit1_acc: 0.5668 - digit2_acc: 0.6445 - digit3_acc: 0.6481 - digit4_acc: 0.5450 - digit5_acc: 0.6153 - digit6_acc: 0.6358 - digit7_acc: 0.5518 - val_loss: 7.5591 - val_digit1_loss: 1.1211 - val_digit2_loss: 0.9965 - val_digit3_loss: 0.9561 - val_digit4_loss: 1.2212 - val_digit5_loss: 1.0413 - val_digit6_loss: 1.0056 - val_digit7_loss: 1.2173 - val_digit1_acc: 0.6801 - val_digit2_acc: 0.7255 - val_digit3_acc: 0.7326 - val_digit4_acc: 0.6458 - val_digit5_acc: 0.7105 - val_digit6_acc: 0.7167 - val_digit7_acc: 0.6431
# Epoch 15/30
# 72000/72000 [==============================] - 92s 1ms/step - loss: 8.5178 - digit1_loss: 1.2930 - digit2_loss: 1.1090 - digit3_loss: 1.0941 - digit4_loss: 1.3707 - digit5_loss: 1.1841 - digit6_loss: 1.1302 - digit7_loss: 1.3367 - digit1_acc: 0.5820 - digit2_acc: 0.6535 - digit3_acc: 0.6585 - digit4_acc: 0.5541 - digit5_acc: 0.6266 - digit6_acc: 0.6465 - digit7_acc: 0.5638 - val_loss: 7.3759 - val_digit1_loss: 1.1052 - val_digit2_loss: 0.9593 - val_digit3_loss: 0.9244 - val_digit4_loss: 1.1978 - val_digit5_loss: 1.0320 - val_digit6_loss: 0.9744 - val_digit7_loss: 1.1828 - val_digit1_acc: 0.6898 - val_digit2_acc: 0.7381 - val_digit3_acc: 0.7474 - val_digit4_acc: 0.6548 - val_digit5_acc: 0.7116 - val_digit6_acc: 0.7262 - val_digit7_acc: 0.6624
# Epoch 16/30
# 72000/72000 [==============================] - 95s 1ms/step - loss: 8.3293 - digit1_loss: 1.2646 - digit2_loss: 1.0767 - digit3_loss: 1.0744 - digit4_loss: 1.3432 - digit5_loss: 1.1550 - digit6_loss: 1.0989 - digit7_loss: 1.3165 - digit1_acc: 0.5908 - digit2_acc: 0.6643 - digit3_acc: 0.6640 - digit4_acc: 0.5639 - digit5_acc: 0.6343 - digit6_acc: 0.6563 - digit7_acc: 0.5697 - val_loss: 7.2429 - val_digit1_loss: 1.0751 - val_digit2_loss: 0.9463 - val_digit3_loss: 0.9121 - val_digit4_loss: 1.1823 - val_digit5_loss: 1.0011 - val_digit6_loss: 0.9610 - val_digit7_loss: 1.1649 - val_digit1_acc: 0.6982 - val_digit2_acc: 0.7419 - val_digit3_acc: 0.7508 - val_digit4_acc: 0.6571 - val_digit5_acc: 0.7215 - val_digit6_acc: 0.7307 - val_digit7_acc: 0.6621
# Epoch 17/30
# 72000/72000 [==============================] - 96s 1ms/step - loss: 8.1552 - digit1_loss: 1.2414 - digit2_loss: 1.0513 - digit3_loss: 1.0489 - digit4_loss: 1.3167 - digit5_loss: 1.1261 - digit6_loss: 1.0751 - digit7_loss: 1.2956 - digit1_acc: 0.5979 - digit2_acc: 0.6731 - digit3_acc: 0.6729 - digit4_acc: 0.5730 - digit5_acc: 0.6441 - digit6_acc: 0.6638 - digit7_acc: 0.5774 - val_loss: 7.0911 - val_digit1_loss: 1.0550 - val_digit2_loss: 0.9259 - val_digit3_loss: 0.8956 - val_digit4_loss: 1.1589 - val_digit5_loss: 0.9768 - val_digit6_loss: 0.9427 - val_digit7_loss: 1.1362 - val_digit1_acc: 0.7056 - val_digit2_acc: 0.7460 - val_digit3_acc: 0.7573 - val_digit4_acc: 0.6716 - val_digit5_acc: 0.7326 - val_digit6_acc: 0.7411 - val_digit7_acc: 0.6742
# Epoch 18/30
# 72000/72000 [==============================] - 96s 1ms/step - loss: 8.0017 - digit1_loss: 1.2248 - digit2_loss: 1.0277 - digit3_loss: 1.0257 - digit4_loss: 1.2937 - digit5_loss: 1.1086 - digit6_loss: 1.0501 - digit7_loss: 1.2711 - digit1_acc: 0.6032 - digit2_acc: 0.6800 - digit3_acc: 0.6800 - digit4_acc: 0.5829 - digit5_acc: 0.6513 - digit6_acc: 0.6737 - digit7_acc: 0.5851 - val_loss: 6.9437 - val_digit1_loss: 1.0345 - val_digit2_loss: 0.9015 - val_digit3_loss: 0.8714 - val_digit4_loss: 1.1285 - val_digit5_loss: 0.9636 - val_digit6_loss: 0.9200 - val_digit7_loss: 1.1241 - val_digit1_acc: 0.7123 - val_digit2_acc: 0.7552 - val_digit3_acc: 0.7637 - val_digit4_acc: 0.6807 - val_digit5_acc: 0.7380 - val_digit6_acc: 0.7442 - val_digit7_acc: 0.6742
# Epoch 19/30
# 72000/72000 [==============================] - 91s 1ms/step - loss: 7.8528 - digit1_loss: 1.2019 - digit2_loss: 1.0090 - digit3_loss: 1.0034 - digit4_loss: 1.2717 - digit5_loss: 1.0882 - digit6_loss: 1.0276 - digit7_loss: 1.2511 - digit1_acc: 0.6106 - digit2_acc: 0.6858 - digit3_acc: 0.6862 - digit4_acc: 0.5919 - digit5_acc: 0.6577 - digit6_acc: 0.6773 - digit7_acc: 0.5948 - val_loss: 6.7385 - val_digit1_loss: 0.9957 - val_digit2_loss: 0.8728 - val_digit3_loss: 0.8474 - val_digit4_loss: 1.1085 - val_digit5_loss: 0.9269 - val_digit6_loss: 0.8922 - val_digit7_loss: 1.0950 - val_digit1_acc: 0.7246 - val_digit2_acc: 0.7652 - val_digit3_acc: 0.7694 - val_digit4_acc: 0.6855 - val_digit5_acc: 0.7479 - val_digit6_acc: 0.7563 - val_digit7_acc: 0.6887
# Epoch 20/30
# 72000/72000 [==============================] - 90s 1ms/step - loss: 7.7383 - digit1_loss: 1.1876 - digit2_loss: 0.9910 - digit3_loss: 0.9883 - digit4_loss: 1.2570 - digit5_loss: 1.0715 - digit6_loss: 1.0091 - digit7_loss: 1.2339 - digit1_acc: 0.6149 - digit2_acc: 0.6913 - digit3_acc: 0.6933 - digit4_acc: 0.5923 - digit5_acc: 0.6634 - digit6_acc: 0.6856 - digit7_acc: 0.6003 - val_loss: 6.6546 - val_digit1_loss: 0.9879 - val_digit2_loss: 0.8645 - val_digit3_loss: 0.8317 - val_digit4_loss: 1.0844 - val_digit5_loss: 0.9106 - val_digit6_loss: 0.8841 - val_digit7_loss: 1.0913 - val_digit1_acc: 0.7292 - val_digit2_acc: 0.7691 - val_digit3_acc: 0.7764 - val_digit4_acc: 0.6953 - val_digit5_acc: 0.7544 - val_digit6_acc: 0.7558 - val_digit7_acc: 0.6924
# Epoch 21/30
# 72000/72000 [==============================] - 89s 1ms/step - loss: 7.6092 - digit1_loss: 1.1632 - digit2_loss: 0.9733 - digit3_loss: 0.9717 - digit4_loss: 1.2387 - digit5_loss: 1.0498 - digit6_loss: 0.9934 - digit7_loss: 1.2191 - digit1_acc: 0.6277 - digit2_acc: 0.6974 - digit3_acc: 0.6981 - digit4_acc: 0.6000 - digit5_acc: 0.6716 - digit6_acc: 0.6903 - digit7_acc: 0.6037 - val_loss: 6.5113 - val_digit1_loss: 0.9698 - val_digit2_loss: 0.8437 - val_digit3_loss: 0.8229 - val_digit4_loss: 1.0625 - val_digit5_loss: 0.8950 - val_digit6_loss: 0.8614 - val_digit7_loss: 1.0558 - val_digit1_acc: 0.7349 - val_digit2_acc: 0.7735 - val_digit3_acc: 0.7797 - val_digit4_acc: 0.7054 - val_digit5_acc: 0.7581 - val_digit6_acc: 0.7639 - val_digit7_acc: 0.7012
# Epoch 22/30
# 72000/72000 [==============================] - 89s 1ms/step - loss: 7.5166 - digit1_loss: 1.1510 - digit2_loss: 0.9578 - digit3_loss: 0.9577 - digit4_loss: 1.2269 - digit5_loss: 1.0374 - digit6_loss: 0.9823 - digit7_loss: 1.2035 - digit1_acc: 0.6299 - digit2_acc: 0.7009 - digit3_acc: 0.7034 - digit4_acc: 0.6032 - digit5_acc: 0.6753 - digit6_acc: 0.6946 - digit7_acc: 0.6103 - val_loss: 6.4330 - val_digit1_loss: 0.9520 - val_digit2_loss: 0.8358 - val_digit3_loss: 0.8073 - val_digit4_loss: 1.0578 - val_digit5_loss: 0.8863 - val_digit6_loss: 0.8460 - val_digit7_loss: 1.0477 - val_digit1_acc: 0.7423 - val_digit2_acc: 0.7808 - val_digit3_acc: 0.7878 - val_digit4_acc: 0.7036 - val_digit5_acc: 0.7638 - val_digit6_acc: 0.7713 - val_digit7_acc: 0.7051
# Epoch 23/30
# 72000/72000 [==============================] - 89s 1ms/step - loss: 7.3932 - digit1_loss: 1.1341 - digit2_loss: 0.9434 - digit3_loss: 0.9361 - digit4_loss: 1.2103 - digit5_loss: 1.0168 - digit6_loss: 0.9651 - digit7_loss: 1.1874 - digit1_acc: 0.6338 - digit2_acc: 0.7070 - digit3_acc: 0.7110 - digit4_acc: 0.6116 - digit5_acc: 0.6808 - digit6_acc: 0.6997 - digit7_acc: 0.6163 - val_loss: 6.3969 - val_digit1_loss: 0.9424 - val_digit2_loss: 0.8374 - val_digit3_loss: 0.7973 - val_digit4_loss: 1.0461 - val_digit5_loss: 0.8807 - val_digit6_loss: 0.8499 - val_digit7_loss: 1.0432 - val_digit1_acc: 0.7474 - val_digit2_acc: 0.7774 - val_digit3_acc: 0.7879 - val_digit4_acc: 0.7080 - val_digit5_acc: 0.7657 - val_digit6_acc: 0.7699 - val_digit7_acc: 0.7096
# Epoch 24/30
# 72000/72000 [==============================] - 95s 1ms/step - loss: 7.3168 - digit1_loss: 1.1227 - digit2_loss: 0.9331 - digit3_loss: 0.9309 - digit4_loss: 1.2034 - digit5_loss: 1.0013 - digit6_loss: 0.9507 - digit7_loss: 1.1747 - digit1_acc: 0.6399 - digit2_acc: 0.7103 - digit3_acc: 0.7115 - digit4_acc: 0.6151 - digit5_acc: 0.6873 - digit6_acc: 0.7040 - digit7_acc: 0.6217 - val_loss: 6.3568 - val_digit1_loss: 0.9318 - val_digit2_loss: 0.8214 - val_digit3_loss: 0.8032 - val_digit4_loss: 1.0434 - val_digit5_loss: 0.8740 - val_digit6_loss: 0.8441 - val_digit7_loss: 1.0389 - val_digit1_acc: 0.7492 - val_digit2_acc: 0.7859 - val_digit3_acc: 0.7878 - val_digit4_acc: 0.7123 - val_digit5_acc: 0.7690 - val_digit6_acc: 0.7708 - val_digit7_acc: 0.7099
# Epoch 25/30
# 72000/72000 [==============================] - 91s 1ms/step - loss: 7.2219 - digit1_loss: 1.1113 - digit2_loss: 0.9235 - digit3_loss: 0.9135 - digit4_loss: 1.1867 - digit5_loss: 0.9920 - digit6_loss: 0.9389 - digit7_loss: 1.1559 - digit1_acc: 0.6421 - digit2_acc: 0.7140 - digit3_acc: 0.7157 - digit4_acc: 0.6182 - digit5_acc: 0.6900 - digit6_acc: 0.7096 - digit7_acc: 0.6248 - val_loss: 6.2208 - val_digit1_loss: 0.9165 - val_digit2_loss: 0.8048 - val_digit3_loss: 0.7847 - val_digit4_loss: 1.0185 - val_digit5_loss: 0.8535 - val_digit6_loss: 0.8239 - val_digit7_loss: 1.0190 - val_digit1_acc: 0.7541 - val_digit2_acc: 0.7892 - val_digit3_acc: 0.7947 - val_digit4_acc: 0.7192 - val_digit5_acc: 0.7763 - val_digit6_acc: 0.7780 - val_digit7_acc: 0.7152
# Epoch 26/30
# 65120/72000 [==========================>...] - ETA: 8s - loss: 7.1309 - digit1_loss: 1.0939 - digit2_loss: 0.9064 - digit3_loss: 0.9023 - digit4_loss: 1.1721 - digit5_loss: 0.9829 - digit6_loss: 0.9315 - digit7_loss: 1.1418 - digit1_acc: 0.6501 - digit2_acc: 0.7175 - digit3_acc: 0.7208 - digit4_acc: 0.6217 - digit5_acc: 0.6917 - digit6_acc: 0.7106 - digit7_acc: 0.6313Buffered data was truncated after reaching the output size limit.

# %%
plt.figure(figsize=(12,7))
legend_acc = []
for item in hist.history.keys():
  if item.split('_')[-1:] == ['acc']:
    #print("Accuracy = ",item)
    legend_acc.append(item)
    plt.plot(hist.history[item])
plt.ylabel('Accuracy ->')
plt.xlabel('Epoch ->')
plt.legend(legend_acc, loc='upper left')
plt.show()

plt.figure(figsize=(12,7))
legend_acc = []
for item in hist.history.keys():
  if item.split('_')[-1:] == ['loss']:
    #print("Accuracy = ",item)
    legend_acc.append(item)
    plt.plot(hist.history[item])
plt.ylabel('Loss ->')
plt.xlabel('Epoch ->')
plt.legend(legend_acc, loc='upper right')
plt.show()

# %%
# Define function to predict captcha
def predict(filepath):
    img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    ret,thresh = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
    # firstly perform erosion
    erosion = cv2.erode(thresh,kernel,iterations = 1)
    # perform dialation
    dialate = cv2.dilate(erosion,kernel,iterations = 1)
    img = dialate.copy()
    if img is not None:
        img = img / 255.0
    else:
        print("Not detected");
    #res = np.array(model.predict(img[np.newaxis, :, :, np.newaxis]))
    new_im = img.reshape((img.shape[1],img.shape[0]))
    res = np.array(model.predict(new_im[np.newaxis,:,:,np.newaxis]))
    #print(res)
    ans = np.reshape(res, (7, 36))
    l_ind = []
    probs = []
    for a in ans:
        l_ind.append(np.argmax(a))
        #probs.append(np.max(a))

    capt = ''
    for l in l_ind:
        capt += symbols[l]
    return capt#, sum(probs) / 5

# %%
total_img = 36
num_pr = 6 # number per row

counter = 1
plt.figure(figsize=(30,15))
plt.axis('off')
for item in png_files[:total_img]:
  image = cv2.imread(item, cv2.IMREAD_UNCHANGED)
  pred = predict(item)
  #print(pred)
  image_bckup = image.copy()
  plt.subplot(num_pr, num_pr, counter)
  #print("item => ",item)
  #print("item => ",str(item.split('_')[1]).split('/')[1])
  if str(item.split('_')[1]).split('/')[1] == str(pred):
    plt.title("Prediction = {}".format(pred),fontsize=20).set_color('green')
  else:
    plt.title("Prediction = {}".format(pred),fontsize=20).set_color('red')
  plt.axis('off')
  plt.imshow(image_bckup, cmap=plt.get_cmap('gray'))
  counter += 1
  #break
plt.show()

# %%
score= model.evaluate(X_test,[y_train[0], y_train[1], y_train[2],y_train[3],y_train[4],y_train[5],y_train[6]],verbose=1)
print('Test Loss and accuracy:', score)
model.evaluate(X_test, [y_train[0], y_train[1], y_train[2],y_train[3],y_train[4],y_train[5],y_train[6]])

# %%
# download the model in computer for later use

model.save('railway_captcha_7_imop.h5')
# download the model from colab
from google.colab import files
files.download('railway_captcha_7_imop.h5')
