# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#img_path = "0000_55576.jpg"
#img_path = "0A78_69181.jpg"
#img_path = "0000_55938.jpg"
#img_path = "0A87_20173.jpg"
#img_path = "0A60_8851.jpg"
img = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)
plt.imshow(img,cmap='gray')
plt.show()

# %%
blur = img.copy()
blur.astype(dtype=np.uint8)
for item in range(4):
    blur = cv2.GaussianBlur(blur,(3,3),0)
    #blur = cv2.blur(blur,(5,5))
plt.imshow(blur,cmap='gray')
plt.show()

# %%
blur_thesh = cv2.threshold(blur,170,200,cv2.THRESH_BINARY_INV)
plt.imshow(blur_thesh[1])
plt.show()

# %%
adapt_thres = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,21,2)
plt.imshow(255-adapt_thres,cmap='gray')
plt.show()
