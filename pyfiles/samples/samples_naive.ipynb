# %%
# dont ask me, and I won't clean it..
import numpy as np
import glob
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import os
# %tensorflow_version 1.x
from PIL import Image
from keras import layers
from keras.models import Model
from keras.models import load_model
from keras.utils.vis_utils import plot_model  #plotting the model structure
from keras import callbacks
from datetime import datetime
import os
import cv2
import string
import numpy as np


from keras.models import Model
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
import warnings
warnings.filterwarnings('ignore')
from keras import models
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint


from keras import layers        # functional 
from keras.models import Model
from keras.models import load_model
from keras import callbacks
import cv2
import string
import numpy as np
from datetime import datetime
from packaging import version
import tensorflow as tf
from tensorflow import keras
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
#! rm -rf railway_captcha3.tar.gz
! wget "https://ndownloader.figshare.com/files/22149861" -O samples.tar.gz
# Out:
# --2020-04-08 09:08:29--  https://ndownloader.figshare.com/files/22149861
# Resolving ndownloader.figshare.com (ndownloader.figshare.com)... 34.242.31.21, 34.246.188.184, 34.246.143.19, ...
# Connecting to ndownloader.figshare.com (ndownloader.figshare.com)|34.242.31.21|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/22149861/samples.tar.gz [following]
# --2020-04-08 09:08:30--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/22149861/samples.tar.gz
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.100.203
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.100.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 390645514 (373M) [application/gzip]
# Saving to: ‘samples.tar.gz’
#
# samples.tar.gz      100%[===================>] 372.55M  81.9MB/s    in 4.5s
#
# 2020-04-08 09:08:34 (83.0 MB/s) - ‘samples.tar.gz’ saved [390645514/390645514]

# %%
! tar -xvf samples.tar.gz > /dev/null
! echo "Untaring... done..."
# Out:
# Untaring... done...

# %%
png_files = glob.glob('samples/*.png')
print("Total # of files => ",len(png_files))
png_files[0]
# Out:
# Total # of files =>  10000
# 'samples/2634.png'

# %%
symbols = '0123456789' # These are all symbols the captchas will have
num_symbols = len(symbols)
img = np.array(Image.open(png_files[0]))
shape_ = img.shape
print(shape_,"number of Symbols = ", num_symbols)
# Out:
# (100, 200, 3) number of Symbols =  10

# %%
img_path = png_files[1]
img = cv2.imread(img_path,cv2.IMREAD_UNCHANGED)
plt.imshow(img[:,:,::-1])
plt.show()

# %%
# thresholding binary inverse

img_path = png_files[1]
img = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)
#ret,thresh = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
plt.imshow(img,cmap='gray')
plt.show()

# %%
# adaptive thresholding
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)
plt.imshow(th3,cmap='gray')
plt.show()

# %%
# mean adaptive thresholding
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
plt.imshow(th2,cmap='gray')
plt.show()

# %%
ret2,thres = cv2.threshold(img,0,255,cv2.THRESH_TOZERO+cv2.THRESH_OTSU)
plt.imshow(thres,cmap='gray')
plt.show()

# %%
im_thres = thresh-(255-thres)
plt.imshow(im_thres,cmap='gray')
plt.show()

# %%
png_files[0]
# Out:
# 'samples/2634.png'

# %%
from tqdm import tqdm
kernel = np.ones((2,2),np.uint8)

def preprocess_data():
  n_samples = len(os.listdir('samples/'))
  X = np.zeros((n_samples, 200, 100, 1)) #1070*50*200
  print(num_symbols,n_samples)
  y = np.zeros((4, n_samples, num_symbols)) #5*1070*36
  for i, pic in tqdm(enumerate(os.listdir('samples/'))):
    # Read image as grayscale
    img = cv2.imread(os.path.join('samples/', pic), cv2.IMREAD_GRAYSCALE)
    pic_target = pic.split('.')[0]
    # plt.imshow(img,cmap='gray')
    # plt.show()
    # break
    img = img / 255.0
    #plt.imshow(img,cmap='gray')
    img = np.reshape(img, (200, 100, 1))
    # Define targets and code them using OneHotEncoding
    targs = np.zeros((4, num_symbols))
    #print("num symbols = ",num_symbols)
    for j, l in enumerate(pic_target):
      ind = symbols.find(l)
      targs[j, ind] = 1
    X[i] = img
    y[:, i] = targs
    
  # Return final data
  return X, y

X, y = preprocess_data()
# Out:
# 119it [00:00, 1182.96it/s]
# 10 10000
# 10000it [00:08, 1183.31it/s]

# %%
#print(X[0])
print(X.shape)
print(X[0].shape)
#print(y[0])
print(y.shape)
print(y[0].shape)
# Out:
# (10000, 200, 100, 1)
# (200, 100, 1)
# (4, 10000, 10)
# (10000, 10)

# %%
X_train, y_train = X[:9000], y[:, :9000]
X_test, y_test = X[9000:], y[:, 9000:]

# %%
plt.imshow(X_train[0].reshape((100,200)),cmap='gray')
plt.show()
print(X_train[0].shape)
# Out:
# (200, 100, 1)

# %%
def create_model():
  in_ = Input(shape=img_shape)
  out = in_
  out = Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu')(out)
  out = Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Dropout(0.3)(out)
  out = Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(out)
  out = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Dropout(0.3)(out)
  out = Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(out)
  out = Conv2D(filters=128, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Dropout(0.3)(out)
  out = Conv2D(filters=256, kernel_size=(3, 3), activation='relu')(out)
  out = BatchNormalization()(out)
  out = MaxPooling2D(pool_size=(2, 2))(out)
  out = Flatten()(out)
  out = Dropout(0.3)(out)
  out = [Dense(10, name='digit1', activation='softmax')(out),\
      Dense(10, name='digit2', activation='softmax')(out),\
      Dense(10, name='digit3', activation='softmax')(out),\
      Dense(10, name='digit4', activation='softmax')(out)]
      #Dense(36, name='digit5', activation='softmax')(out)]
  model = Model(inputs=in_, outputs=out)
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
img_shape = (200, 100, 1)
model=create_model();
model.summary();
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 100, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 200, 100, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 198, 98, 32)  9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 198, 98, 32)  128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 99, 49, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 99, 49, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 99, 49, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 97, 47, 64)   36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 97, 47, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 48, 23, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 48, 23, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 23, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 46, 21, 128)  147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 46, 21, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 23, 10, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 23, 10, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 21, 8, 256)   295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 21, 8, 256)   1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 10, 4, 256)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10240)        0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10240)        0           flatten_1[0][0]
# __________________________________________________________________________________________________
# digit1 (Dense)                  (None, 10)           102410      dropout_4[0][0]
# __________________________________________________________________________________________________
# digit2 (Dense)                  (None, 10)           102410      dropout_4[0][0]
# __________________________________________________________________________________________________
# digit3 (Dense)                  (None, 10)           102410      dropout_4[0][0]
# __________________________________________________________________________________________________
# digit4 (Dense)                  (None, 10)           102410      dropout_4[0][0]
# ==================================================================================================
# Total params: 993,160
# Trainable params: 992,200
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True,dpi=60)

# %%
# for storing logs into tensorboard
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

hist = model.fit(X_train, [y_train[0], y_train[1], y_train[2],y_train[3]], batch_size=32, epochs=30,verbose=1, validation_split=0.2,callbacks=[tensorboard_callback])
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 7200 samples, validate on 1800 samples
# Epoch 1/30
# 7200/7200 [==============================] - 57s 8ms/step - loss: 12.4465 - digit1_loss: 3.1050 - digit2_loss: 3.1260 - digit3_loss: 3.2046 - digit4_loss: 3.0109 - digit1_acc: 0.1029 - digit2_acc: 0.1007 - digit3_acc: 0.1040 - digit4_acc: 0.1065 - val_loss: 18.4359 - val_digit1_loss: 3.9377 - val_digit2_loss: 4.0317 - val_digit3_loss: 5.4437 - val_digit4_loss: 5.0228 - val_digit1_acc: 0.1033 - val_digit2_acc: 0.1278 - val_digit3_acc: 0.1017 - val_digit4_acc: 0.1100
# Epoch 2/30
# 7200/7200 [==============================] - 47s 7ms/step - loss: 9.9603 - digit1_loss: 2.4953 - digit2_loss: 2.4781 - digit3_loss: 2.5024 - digit4_loss: 2.4846 - digit1_acc: 0.1133 - digit2_acc: 0.1111 - digit3_acc: 0.1043 - digit4_acc: 0.1085 - val_loss: 9.4873 - val_digit1_loss: 2.4154 - val_digit2_loss: 2.3352 - val_digit3_loss: 2.3723 - val_digit4_loss: 2.3644 - val_digit1_acc: 0.1106 - val_digit2_acc: 0.1117 - val_digit3_acc: 0.1128 - val_digit4_acc: 0.1200
# Epoch 3/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 9.6394 - digit1_loss: 2.3936 - digit2_loss: 2.4121 - digit3_loss: 2.4266 - digit4_loss: 2.4071 - digit1_acc: 0.1325 - digit2_acc: 0.1132 - digit3_acc: 0.1154 - digit4_acc: 0.1218 - val_loss: 10.0629 - val_digit1_loss: 2.6644 - val_digit2_loss: 2.4953 - val_digit3_loss: 2.4756 - val_digit4_loss: 2.4277 - val_digit1_acc: 0.1033 - val_digit2_acc: 0.1033 - val_digit3_acc: 0.1122 - val_digit4_acc: 0.1211
# Epoch 4/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 9.3905 - digit1_loss: 2.3324 - digit2_loss: 2.3638 - digit3_loss: 2.3618 - digit4_loss: 2.3325 - digit1_acc: 0.1296 - digit2_acc: 0.1232 - digit3_acc: 0.1304 - digit4_acc: 0.1339 - val_loss: 10.0943 - val_digit1_loss: 2.3739 - val_digit2_loss: 2.5968 - val_digit3_loss: 2.5267 - val_digit4_loss: 2.5968 - val_digit1_acc: 0.1228 - val_digit2_acc: 0.1122 - val_digit3_acc: 0.1200 - val_digit4_acc: 0.1311
# Epoch 5/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 9.0792 - digit1_loss: 2.2639 - digit2_loss: 2.2979 - digit3_loss: 2.2893 - digit4_loss: 2.2282 - digit1_acc: 0.1617 - digit2_acc: 0.1503 - digit3_acc: 0.1568 - digit4_acc: 0.1846 - val_loss: 10.0751 - val_digit1_loss: 2.6545 - val_digit2_loss: 2.3881 - val_digit3_loss: 2.5710 - val_digit4_loss: 2.4614 - val_digit1_acc: 0.1233 - val_digit2_acc: 0.1317 - val_digit3_acc: 0.1339 - val_digit4_acc: 0.1139
# Epoch 6/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 8.6855 - digit1_loss: 2.1769 - digit2_loss: 2.2087 - digit3_loss: 2.1783 - digit4_loss: 2.1216 - digit1_acc: 0.2039 - digit2_acc: 0.1876 - digit3_acc: 0.1964 - digit4_acc: 0.2249 - val_loss: 9.3725 - val_digit1_loss: 2.2577 - val_digit2_loss: 2.4535 - val_digit3_loss: 2.4309 - val_digit4_loss: 2.2304 - val_digit1_acc: 0.1694 - val_digit2_acc: 0.1422 - val_digit3_acc: 0.1522 - val_digit4_acc: 0.2000
# Epoch 7/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 8.2636 - digit1_loss: 2.0721 - digit2_loss: 2.1190 - digit3_loss: 2.0722 - digit4_loss: 2.0004 - digit1_acc: 0.2424 - digit2_acc: 0.2324 - digit3_acc: 0.2478 - digit4_acc: 0.2754 - val_loss: 9.2479 - val_digit1_loss: 2.2666 - val_digit2_loss: 2.3931 - val_digit3_loss: 2.4481 - val_digit4_loss: 2.1401 - val_digit1_acc: 0.1961 - val_digit2_acc: 0.1522 - val_digit3_acc: 0.1672 - val_digit4_acc: 0.2533
# Epoch 8/30
# 7200/7200 [==============================] - 47s 7ms/step - loss: 7.7923 - digit1_loss: 1.9710 - digit2_loss: 2.0030 - digit3_loss: 1.9589 - digit4_loss: 1.8594 - digit1_acc: 0.2882 - digit2_acc: 0.2781 - digit3_acc: 0.3012 - digit4_acc: 0.3453 - val_loss: 8.6469 - val_digit1_loss: 2.0927 - val_digit2_loss: 2.2558 - val_digit3_loss: 2.2295 - val_digit4_loss: 2.0688 - val_digit1_acc: 0.2550 - val_digit2_acc: 0.2322 - val_digit3_acc: 0.2194 - val_digit4_acc: 0.2556
# Epoch 9/30
# 7200/7200 [==============================] - 47s 7ms/step - loss: 7.1712 - digit1_loss: 1.7939 - digit2_loss: 1.8761 - digit3_loss: 1.8155 - digit4_loss: 1.6857 - digit1_acc: 0.3643 - digit2_acc: 0.3403 - digit3_acc: 0.3618 - digit4_acc: 0.4136 - val_loss: 9.5081 - val_digit1_loss: 2.1736 - val_digit2_loss: 2.3454 - val_digit3_loss: 2.4047 - val_digit4_loss: 2.5844 - val_digit1_acc: 0.2628 - val_digit2_acc: 0.2333 - val_digit3_acc: 0.2322 - val_digit4_acc: 0.2356
# Epoch 10/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 6.4793 - digit1_loss: 1.6188 - digit2_loss: 1.7086 - digit3_loss: 1.6875 - digit4_loss: 1.4644 - digit1_acc: 0.4318 - digit2_acc: 0.4097 - digit3_acc: 0.4203 - digit4_acc: 0.4981 - val_loss: 22.2136 - val_digit1_loss: 3.9998 - val_digit2_loss: 6.5116 - val_digit3_loss: 6.7803 - val_digit4_loss: 4.9219 - val_digit1_acc: 0.1850 - val_digit2_acc: 0.1311 - val_digit3_acc: 0.1411 - val_digit4_acc: 0.1633
# Epoch 11/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 5.7294 - digit1_loss: 1.3892 - digit2_loss: 1.5616 - digit3_loss: 1.5574 - digit4_loss: 1.2212 - digit1_acc: 0.5167 - digit2_acc: 0.4547 - digit3_acc: 0.4651 - digit4_acc: 0.5933 - val_loss: 8.1932 - val_digit1_loss: 1.7950 - val_digit2_loss: 1.9802 - val_digit3_loss: 2.1115 - val_digit4_loss: 2.3065 - val_digit1_acc: 0.4083 - val_digit2_acc: 0.3294 - val_digit3_acc: 0.3061 - val_digit4_acc: 0.3689
# Epoch 12/30
# 7200/7200 [==============================] - 47s 7ms/step - loss: 5.0635 - digit1_loss: 1.2006 - digit2_loss: 1.4225 - digit3_loss: 1.4199 - digit4_loss: 1.0205 - digit1_acc: 0.5900 - digit2_acc: 0.5086 - digit3_acc: 0.5083 - digit4_acc: 0.6565 - val_loss: 36.3686 - val_digit1_loss: 7.1602 - val_digit2_loss: 10.7205 - val_digit3_loss: 11.3451 - val_digit4_loss: 7.1428 - val_digit1_acc: 0.1528 - val_digit2_acc: 0.1217 - val_digit3_acc: 0.1200 - val_digit4_acc: 0.1633
# Epoch 13/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 4.3887 - digit1_loss: 1.0019 - digit2_loss: 1.2900 - digit3_loss: 1.2731 - digit4_loss: 0.8237 - digit1_acc: 0.6614 - digit2_acc: 0.5550 - digit3_acc: 0.5594 - digit4_acc: 0.7297 - val_loss: 9.8455 - val_digit1_loss: 1.8909 - val_digit2_loss: 3.2901 - val_digit3_loss: 3.0340 - val_digit4_loss: 1.6306 - val_digit1_acc: 0.4056 - val_digit2_acc: 0.2250 - val_digit3_acc: 0.2411 - val_digit4_acc: 0.4811
# Epoch 14/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 3.8679 - digit1_loss: 0.8522 - digit2_loss: 1.1522 - digit3_loss: 1.1567 - digit4_loss: 0.7068 - digit1_acc: 0.7090 - digit2_acc: 0.5971 - digit3_acc: 0.6012 - digit4_acc: 0.7675 - val_loss: 6.2430 - val_digit1_loss: 1.2725 - val_digit2_loss: 1.9735 - val_digit3_loss: 1.9265 - val_digit4_loss: 1.0706 - val_digit1_acc: 0.5678 - val_digit2_acc: 0.3661 - val_digit3_acc: 0.3683 - val_digit4_acc: 0.6411
# Epoch 15/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 3.3905 - digit1_loss: 0.7119 - digit2_loss: 1.0434 - digit3_loss: 1.0432 - digit4_loss: 0.5919 - digit1_acc: 0.7585 - digit2_acc: 0.6431 - digit3_acc: 0.6383 - digit4_acc: 0.8006 - val_loss: 5.7244 - val_digit1_loss: 1.1459 - val_digit2_loss: 1.7039 - val_digit3_loss: 1.8114 - val_digit4_loss: 1.0632 - val_digit1_acc: 0.6161 - val_digit2_acc: 0.4411 - val_digit3_acc: 0.4239 - val_digit4_acc: 0.6522
# Epoch 16/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 2.9421 - digit1_loss: 0.5935 - digit2_loss: 0.9222 - digit3_loss: 0.9318 - digit4_loss: 0.4946 - digit1_acc: 0.7992 - digit2_acc: 0.6826 - digit3_acc: 0.6736 - digit4_acc: 0.8321 - val_loss: 6.5662 - val_digit1_loss: 1.1835 - val_digit2_loss: 2.3110 - val_digit3_loss: 2.1073 - val_digit4_loss: 0.9644 - val_digit1_acc: 0.6361 - val_digit2_acc: 0.3806 - val_digit3_acc: 0.3922 - val_digit4_acc: 0.6767
# Epoch 17/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 2.6360 - digit1_loss: 0.5148 - digit2_loss: 0.8531 - digit3_loss: 0.8439 - digit4_loss: 0.4242 - digit1_acc: 0.8264 - digit2_acc: 0.7064 - digit3_acc: 0.7139 - digit4_acc: 0.8613 - val_loss: 4.9811 - val_digit1_loss: 0.8480 - val_digit2_loss: 1.6185 - val_digit3_loss: 1.6657 - val_digit4_loss: 0.8489 - val_digit1_acc: 0.7228 - val_digit2_acc: 0.4972 - val_digit3_acc: 0.4717 - val_digit4_acc: 0.7311
# Epoch 18/30
# 7200/7200 [==============================] - 47s 7ms/step - loss: 2.3646 - digit1_loss: 0.4355 - digit2_loss: 0.7720 - digit3_loss: 0.7763 - digit4_loss: 0.3807 - digit1_acc: 0.8533 - digit2_acc: 0.7354 - digit3_acc: 0.7350 - digit4_acc: 0.8712 - val_loss: 11.3032 - val_digit1_loss: 4.5947 - val_digit2_loss: 2.3416 - val_digit3_loss: 3.0064 - val_digit4_loss: 1.3605 - val_digit1_acc: 0.3617 - val_digit2_acc: 0.3972 - val_digit3_acc: 0.3489 - val_digit4_acc: 0.6478
# Epoch 19/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 2.1166 - digit1_loss: 0.4151 - digit2_loss: 0.6853 - digit3_loss: 0.6785 - digit4_loss: 0.3378 - digit1_acc: 0.8581 - digit2_acc: 0.7646 - digit3_acc: 0.7681 - digit4_acc: 0.8913 - val_loss: 4.9385 - val_digit1_loss: 0.8770 - val_digit2_loss: 1.6653 - val_digit3_loss: 1.6601 - val_digit4_loss: 0.7361 - val_digit1_acc: 0.7261 - val_digit2_acc: 0.5033 - val_digit3_acc: 0.5261 - val_digit4_acc: 0.7744
# Epoch 20/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 1.9362 - digit1_loss: 0.3632 - digit2_loss: 0.6404 - digit3_loss: 0.6435 - digit4_loss: 0.2892 - digit1_acc: 0.8754 - digit2_acc: 0.7769 - digit3_acc: 0.7758 - digit4_acc: 0.9035 - val_loss: 4.9893 - val_digit1_loss: 0.8041 - val_digit2_loss: 1.6883 - val_digit3_loss: 1.7788 - val_digit4_loss: 0.7182 - val_digit1_acc: 0.7511 - val_digit2_acc: 0.5156 - val_digit3_acc: 0.4922 - val_digit4_acc: 0.7828
# Epoch 21/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 1.7440 - digit1_loss: 0.3164 - digit2_loss: 0.5990 - digit3_loss: 0.5622 - digit4_loss: 0.2664 - digit1_acc: 0.8917 - digit2_acc: 0.7914 - digit3_acc: 0.8032 - digit4_acc: 0.9081 - val_loss: 5.4765 - val_digit1_loss: 0.7978 - val_digit2_loss: 1.8189 - val_digit3_loss: 1.9050 - val_digit4_loss: 0.9548 - val_digit1_acc: 0.7600 - val_digit2_acc: 0.5061 - val_digit3_acc: 0.4872 - val_digit4_acc: 0.7028
# Epoch 22/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 1.6079 - digit1_loss: 0.2841 - digit2_loss: 0.5387 - digit3_loss: 0.5508 - digit4_loss: 0.2343 - digit1_acc: 0.9054 - digit2_acc: 0.8129 - digit3_acc: 0.8144 - digit4_acc: 0.9217 - val_loss: 13.2144 - val_digit1_loss: 1.7268 - val_digit2_loss: 3.0871 - val_digit3_loss: 3.9226 - val_digit4_loss: 4.4780 - val_digit1_acc: 0.5944 - val_digit2_acc: 0.3600 - val_digit3_acc: 0.3333 - val_digit4_acc: 0.3739
# Epoch 23/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 1.4890 - digit1_loss: 0.2687 - digit2_loss: 0.4901 - digit3_loss: 0.5051 - digit4_loss: 0.2251 - digit1_acc: 0.9060 - digit2_acc: 0.8286 - digit3_acc: 0.8265 - digit4_acc: 0.9242 - val_loss: 4.9271 - val_digit1_loss: 0.7516 - val_digit2_loss: 1.7422 - val_digit3_loss: 1.7392 - val_digit4_loss: 0.6941 - val_digit1_acc: 0.7756 - val_digit2_acc: 0.5428 - val_digit3_acc: 0.5100 - val_digit4_acc: 0.7989
# Epoch 24/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 1.4099 - digit1_loss: 0.2481 - digit2_loss: 0.4744 - digit3_loss: 0.4768 - digit4_loss: 0.2107 - digit1_acc: 0.9137 - digit2_acc: 0.8350 - digit3_acc: 0.8381 - digit4_acc: 0.9285 - val_loss: 6.4981 - val_digit1_loss: 1.1908 - val_digit2_loss: 2.2369 - val_digit3_loss: 2.2410 - val_digit4_loss: 0.8294 - val_digit1_acc: 0.6822 - val_digit2_acc: 0.4800 - val_digit3_acc: 0.4628 - val_digit4_acc: 0.7550
# Epoch 25/30
# 7200/7200 [==============================] - 47s 7ms/step - loss: 1.3223 - digit1_loss: 0.2440 - digit2_loss: 0.4243 - digit3_loss: 0.4508 - digit4_loss: 0.2031 - digit1_acc: 0.9176 - digit2_acc: 0.8554 - digit3_acc: 0.8436 - digit4_acc: 0.9307 - val_loss: 6.0181 - val_digit1_loss: 1.2057 - val_digit2_loss: 2.0296 - val_digit3_loss: 1.9453 - val_digit4_loss: 0.8375 - val_digit1_acc: 0.6844 - val_digit2_acc: 0.4844 - val_digit3_acc: 0.4850 - val_digit4_acc: 0.7578
# Epoch 26/30
# 7200/7200 [==============================] - 47s 7ms/step - loss: 1.2121 - digit1_loss: 0.2168 - digit2_loss: 0.4077 - digit3_loss: 0.4010 - digit4_loss: 0.1865 - digit1_acc: 0.9243 - digit2_acc: 0.8604 - digit3_acc: 0.8640 - digit4_acc: 0.9393 - val_loss: 5.3412 - val_digit1_loss: 0.8263 - val_digit2_loss: 1.8367 - val_digit3_loss: 1.8549 - val_digit4_loss: 0.8233 - val_digit1_acc: 0.7594 - val_digit2_acc: 0.5256 - val_digit3_acc: 0.5122 - val_digit4_acc: 0.7678
# Epoch 27/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 1.1639 - digit1_loss: 0.2006 - digit2_loss: 0.3953 - digit3_loss: 0.3886 - digit4_loss: 0.1795 - digit1_acc: 0.9337 - digit2_acc: 0.8644 - digit3_acc: 0.8649 - digit4_acc: 0.9406 - val_loss: 5.4943 - val_digit1_loss: 0.8330 - val_digit2_loss: 1.8230 - val_digit3_loss: 1.9186 - val_digit4_loss: 0.9197 - val_digit1_acc: 0.7606 - val_digit2_acc: 0.5139 - val_digit3_acc: 0.4978 - val_digit4_acc: 0.7200
# Epoch 28/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 1.1018 - digit1_loss: 0.1974 - digit2_loss: 0.3654 - digit3_loss: 0.3771 - digit4_loss: 0.1620 - digit1_acc: 0.9347 - digit2_acc: 0.8718 - digit3_acc: 0.8657 - digit4_acc: 0.9439 - val_loss: 5.0848 - val_digit1_loss: 0.8349 - val_digit2_loss: 1.7653 - val_digit3_loss: 1.8268 - val_digit4_loss: 0.6578 - val_digit1_acc: 0.7672 - val_digit2_acc: 0.5533 - val_digit3_acc: 0.5356 - val_digit4_acc: 0.8156
# Epoch 29/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 1.0252 - digit1_loss: 0.1706 - digit2_loss: 0.3479 - digit3_loss: 0.3562 - digit4_loss: 0.1505 - digit1_acc: 0.9431 - digit2_acc: 0.8829 - digit3_acc: 0.8757 - digit4_acc: 0.9514 - val_loss: 7.6834 - val_digit1_loss: 1.5778 - val_digit2_loss: 2.4555 - val_digit3_loss: 2.4659 - val_digit4_loss: 1.1842 - val_digit1_acc: 0.6089 - val_digit2_acc: 0.4289 - val_digit3_acc: 0.4533 - val_digit4_acc: 0.7133
# Epoch 30/30
# 7200/7200 [==============================] - 48s 7ms/step - loss: 0.9798 - digit1_loss: 0.1618 - digit2_loss: 0.3460 - digit3_loss: 0.3225 - digit4_loss: 0.1495 - digit1_acc: 0.9472 - digit2_acc: 0.8801 - digit3_acc: 0.8922 - digit4_acc: 0.9511 - val_loss: 24.2162 - val_digit1_loss: 5.8868 - val_digit2_loss: 8.0903 - val_digit3_loss: 7.7179 - val_digit4_loss: 2.5213 - val_digit1_acc: 0.4044 - val_digit2_acc: 0.2328 - val_digit3_acc: 0.2706 - val_digit4_acc: 0.5856

# %%
plt.figure(figsize=(12,7))
legend_acc = []
for item in hist.history.keys():
  if item.split('_')[-1:] == ['acc']:
    #print("Accuracy = ",item)
    legend_acc.append(item)
    plt.plot(hist.history[item])
plt.ylabel('Accuracy ->')
plt.xlabel('Epoch ->')
plt.legend(legend_acc, loc='lower left')
plt.show()

plt.figure(figsize=(12,7))
legend_acc = []
for item in hist.history.keys():
  if item.split('_')[-1:] == ['loss']:
    #print("Accuracy = ",item)
    legend_acc.append(item)
    plt.plot(hist.history[item])
plt.ylabel('Loss ->')
plt.xlabel('Epoch ->')
plt.legend(legend_acc, loc='upper right')
plt.show()

# %%
# download the model in computer for later use

model.save('samples_naive_grayscale.h5')
# download the model from colab
from google.colab import files
files.download('samples_naive.h5')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-2597b5dafc63> in <module>()
#       3 # download the model from colab
#       4 from google.colab import files
# ----> 5 files.download('samples_naive.h5')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     142       raise OSError(msg)
#     143     else:
# --> 144       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     145
#     146   started = _threading.Event()
#
# FileNotFoundError: Cannot find file: samples_naive.h5
